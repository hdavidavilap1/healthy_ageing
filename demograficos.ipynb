# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
os.getcwd()
# Out:
# '/home/hdap/Documents/maestria_unir/practicas/data_david/demografica'

# %%
leer = False

# %%
if leer:
    archivos_leer = [f for f in os.listdir('./') if 'DEMO_' in f]
    archivos = [pd.read_sas(f, format='xport', encoding='utf-8') for f in archivos_leer]
    registros= np.array([(f.shape[0], f.shape[1]) for f in archivos])
    total_registros = registros.sum(axis = 0)[0]
    pd_demo_total = pd.concat(archivos, axis = 0)
    pd_demo_total.to_csv('SEQN.csv', header = True, sep = '|', index = False)

# %%
pd_demo = pd.read_csv('./consolidado_demo.csv', sep = '|')
pd_demo['SEQN'] = pd_demo['SEQN'].astype(int)
pd_demo.shape
# Out:
# (101316, 174)

# %%
pd_demo.SEQN.value_counts().min(), pd_demo.SEQN.value_counts().max()
# Out:
# (1, 1)

# %%
threshold = [60, 70, 80]

[sum(np.where(pd_demo['RIDAGEYR'] >= thr, 1, 0)) for thr in threshold]
# Out:
# [19087, 10207, 4257]

# %%
pd_demo
# Out:
#          SEQN  SDDSRVYR  RIDSTATR  RIAGENDR      RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0       62161       7.0       2.0       1.0  2.200000e+01       NaN       3.0
# 1       62162       7.0       2.0       2.0  3.000000e+00       NaN       1.0
# 2       62163       7.0       2.0       1.0  1.400000e+01       NaN       5.0
# 3       62164       7.0       2.0       2.0  4.400000e+01       NaN       3.0
# 4       62165       7.0       2.0       2.0  1.400000e+01       NaN       4.0
# ...       ...       ...       ...       ...           ...       ...       ...
# 101311  21000       2.0       2.0       2.0  1.000000e+01     126.0       3.0
# 101312  21001       2.0       2.0       1.0  5.397605e-79       8.0       3.0
# 101313  21002       2.0       2.0       1.0  1.000000e+01     120.0       5.0
# 101314  21003       2.0       2.0       1.0  9.000000e+00     116.0       4.0
# 101315  21004       2.0       2.0       1.0  3.100000e+01     372.0       2.0
#
#         RIDRETH3  RIDEXMON  RIDEXAGY  ...  WTIREP50  WTIREP51  WTIREP52  \
# 0            3.0       2.0       NaN  ...       NaN       NaN       NaN
# 1            1.0       1.0       3.0  ...       NaN       NaN       NaN
# 2            6.0       2.0      14.0  ...       NaN       NaN       NaN
# 3            3.0       1.0       NaN  ...       NaN       NaN       NaN
# 4            4.0       2.0      14.0  ...       NaN       NaN       NaN
# ...          ...       ...       ...  ...       ...       ...       ...
# 101311       NaN       2.0       NaN  ...       NaN       NaN       NaN
# 101312       NaN       2.0       NaN  ...       NaN       NaN       NaN
# 101313       NaN       1.0       NaN  ...       NaN       NaN       NaN
# 101314       NaN       1.0       NaN  ...       NaN       NaN       NaN
# 101315       NaN       1.0       NaN  ...       NaN       NaN       NaN
#
#         DMDHRAGZ  DMDHREDZ  DMDHRMAZ  DMDHSEDZ  AIALANG  DMDBORN2  DMDHRBR2
# 0            NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 1            NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 2            NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 4            NaN       NaN       NaN       NaN      NaN       NaN       NaN
# ...          ...       ...       ...       ...      ...       ...       ...
# 101311       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 101312       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 101313       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 101314       NaN       NaN       NaN       NaN      NaN       NaN       NaN
# 101315       NaN       NaN       NaN       NaN      NaN       NaN       NaN
#
# [101316 rows x 174 columns]
